# %% [markdown]
# # Bibliotecas

# %%
## Importando as Bibliotecas Necessárias ##
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import make_classification
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from numpy.linalg import inv
from copy import copy
from sklearn.metrics import RocCurveDisplay

sns.set()

# %%
# Lendo a base de dados
df = pd.read_excel("m.xlsx")

xp = copy(df)

xraw = copy(xp)

xp.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
# 3    Male     Loyal Customer   44  Business travel  Business             3377
# 4  Female     Loyal Customer   49  Business travel       Eco             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              4  ...                       5
# 1                       3              1  ...                       4
# 2                       2              4  ...                       2
# 3                       0              2  ...                       1
# 4                       4              3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 23 columns]

# %% [markdown]
# # Codigo processamento

# %%
df.isnull().sum()
# Out:
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             83
# satisfaction                          0
# dtype: int64

# %%
xp['Arrival Delay in Minutes'] = xp['Arrival Delay in Minutes'].replace(np.nan, 0)

# %%
# Contando a quantidade de dados de cada classe
df=xp
contagem_classes = df['Customer Type'].value_counts()

# Plotando o histograma das classes
plt.figure(figsize=(10, 5))
contagem_classes.plot(kind='bar')
plt.xlabel('Customer Type')
plt.ylabel('Número de Amostras')
plt.title('Histograma do Customer Type em Função do Número de Amostras')
plt.xticks(rotation=360)
plt.show()

# %%
# Contando a quantidade de dados de cada classe
df=xp
contagem_classes = df['Class'].value_counts()

# Plotando o histograma das classes
plt.figure(figsize=(10, 5))
contagem_classes.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Número de Amostras')
plt.title('Histograma da Class em Função do Número de Amostras')
plt.xticks(rotation=360)
plt.show()

# %%
# Contando a quantidade de dados de cada classe
df=xp
contagem_classes = df['Type of Travel'].value_counts()

# Plotando o histograma das classes
plt.figure(figsize=(10, 5))
contagem_classes.plot(kind='bar')
plt.xlabel('Type of Travel')
plt.ylabel('Número de Amostras')
plt.title('Histograma do Type of Travel em Função do Número de Amostras')
plt.xticks(rotation=360)
plt.show()

# %%
# Contando a quantidade de dados de cada classe
df=xp
contagem_classes = df['satisfaction'].value_counts()

# Plotando o histograma das classes
plt.figure(figsize=(10, 5))
contagem_classes.plot(kind='bar')
plt.xlabel('satisfaction')
plt.ylabel('Número de Amostras')
plt.title('Histograma da satisfaction em Função do Número de Amostras')
plt.xticks(rotation=360)
plt.show()

# %%
atributos_numericos = df.select_dtypes(include=['float64', 'int64'])

# Calcula a assimetria para cada atributo numérico
assimetria = atributos_numericos.skew()

# Exibe a assimetria de cada atributo
print(assimetria)
# Out:
# Age                                 -0.000088
# Flight Distance                      1.102927
# Inflight wifi service                0.040792
# Departure/Arrival time convenient   -0.324685
# Ease of Online booking              -0.020655
# Gate location                       -0.055798
# Food and drink                      -0.170229
# Online boarding                     -0.469218
# Seat comfort                        -0.498047
# Inflight entertainment              -0.371353
# On-board service                    -0.426507
# Leg room service                    -0.341210
# Baggage handling                    -0.678863
# Checkin service                     -0.373016
# Inflight service                    -0.696803
# Cleanliness                         -0.304285
# Departure Delay in Minutes           7.193970
# Arrival Delay in Minutes             6.994086
# dtype: float64

# %%
#aplicando histogramas para os atributos contínuos:
def multigraficos_histograma(data, nrows, ncols, nomes):
    fig, axs = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15, 5*nrows))
    k = 0
    for i in range(nrows):
        for j in range(ncols):
            sns.histplot(ax = axs[i,j], data = data, x = nomes[k])
            axs[i, j].set_xlabel(nomes[k])
            axs[i, j].set_ylabel("contagem")
            k+=1
        #
    #
#

nrows = 9
ncols = 2
multigraficos_histograma(df, nrows, ncols, var_num)

# %%
# boxplot

var_num = ['Age', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
           'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service',
           'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness',
           'Departure Delay in Minutes', 'Arrival Delay in Minutes']

nrows = 9
ncols = 2
fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 5*nrows))

for i, var in enumerate(var_num):
    row = i // ncols
    col = i % ncols
    sns.boxplot(ax=axs[row, col], data=df[var].dropna(), orient='h')
    axs[row, col].set_xlabel(var)

plt.tight_layout()

# %%
print("Variaveis com outliers: \n")

dsc = df[var_num].describe() #obtendo estatísticas descritivas dos atributos numericos

for name in dsc.columns:
    q1 = dsc[name]["25%"]
    q3 = dsc[name]["75%"]
    iqr = q3-q1

    min_ = q1 - 1.5*iqr
    max_ = q3 + 1.5*iqr

    out_inf = np.where(df[name] < min_)[0]
    out_sup = np.where(df[name] > max_)[0]

    if ((out_inf.shape[0] > 0) or (out_sup.shape[0] > 0)):
        print(name)
    #
#
# Out:
# Variaveis com outliers:
#
# Flight Distance
# Checkin service
# Departure Delay in Minutes
# Arrival Delay in Minutes

# %% [markdown]
# # Classificação Linear

# %%
df.corr(method='kendall').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c835b_row0_col0, #T_c835b_row1_col1, #T_c835b_row2_col2, #T_c835b_row3_col3, #T_c835b_row4_col4, #T_c835b_row5_col5, #T_c835b_row6_col6, #T_c835b_row7_col7, #T_c835b_row8_col8, #T_c835b_row9_col9, #T_c835b_row10_col10, #T_c835b_row11_col11, #T_c835b_row12_col12, #T_c835b_row13_col13, #T_c835b_row14_col14, #T_c835b_row15_col15, #T_c835b_row16_col16, #T_c835b_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c835b_row0_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c835b_row0_col2, #T_c835b_row3_col16, #T_c835b_row4_col16, #T_c835b_row11_col16, #T_c835b_row12_col5, #T_c835b_row15_col5, #T_c835b_row16_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c835b_row0_col3, #T_c835b_row4_col8, #T_c835b_row4_col13, #T_c835b_row5_col14, #T_c835b_row6_col1, #T_c835b_row8_col5, #T_c835b_row9_col4, #T_c835b_row9_col5, #T_c835b_row10_col4, #T_c835b_row11_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c835b_row0_col4, #T_c835b_row2_col16, #T_c835b_row3_col15, #T_c835b_row6_col16, #T_c835b_row8_col3, #T_c835b_row8_col16, #T_c835b_row9_col17, #T_c835b_row10_col5, #T_c835b_row11_col3, #T_c835b_row12_col16, #T_c835b_row12_col17, #T_c835b_row15_col16, #T_c835b_row16_col14, #T_c835b_row17_col3, #T_c835b_row17_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c835b_row0_col5, #T_c835b_row1_col5, #T_c835b_row4_col17, #T_c835b_row5_col16, #T_c835b_row6_col0, #T_c835b_row6_col11, #T_c835b_row7_col5, #T_c835b_row11_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c835b_row0_
col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c835b_row2_col14, #T_c835b_row15_col14 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c835b_row3_col1, #T_c835b_row5_col13, #T_c835b_row9_col3, #T_c835b_row13_col5, #T_c835b_row14_col0, #T_c835b_row14_col16, #T_c835b_row14_col17, #T_c835b_row16_col4, #T_c835b_row16_col6, #T_c835b_row17_col2, #T_c835b_row17_col4, #T_c835b_row17_col6, #T_c835b_row17_col7, #T_c835b_row17_col8, #T_c835b_row17_col9, #T_c835b_row17_col10, #T_c835b_row17_col11, #T_c835b_row17_col12, #T_c835b_row17_col14, #T_c835b_row17_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c835b_row3_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c835b_row3_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c835b_row3_col5, #T_c835b_row4_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c835b_row3_col6, #T_c835b_row6_col3, #T_c835b_row16_col2, #T_c835b_row16_col15, #T_c835b_row17_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c835b_row3_col7, #T_c835b_row6_col14, #T_c835b_row11_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c835b_row3_col13, #T_c835b_row10_col2, #T_c835b_row12_col8, #T_c835b_row14_col2, #T_c835b_row14_col15 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c835b_row4_col2, #T_c835b_row16_col17 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c835b_row4_col3, #T_c835b_row7_col2, #T_c835b_row9_col14 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c835b_row4_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c835b_row4_col10, #T_c835b_row10_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c835b_row4_col11, #T_c835b_row6_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c835b_row5_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c835b_row5_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c835b_row6_col7, #T_c835b_row13_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c835b_row6_col8 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c835b_row6_col9 {
#   background-color: #edd1c2;

# %%
df.corr(method='spearman').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d8eef_row0_col0, #T_d8eef_row1_col1, #T_d8eef_row2_col2, #T_d8eef_row3_col3, #T_d8eef_row4_col4, #T_d8eef_row5_col5, #T_d8eef_row6_col6, #T_d8eef_row7_col7, #T_d8eef_row8_col8, #T_d8eef_row9_col9, #T_d8eef_row10_col10, #T_d8eef_row11_col11, #T_d8eef_row12_col12, #T_d8eef_row13_col13, #T_d8eef_row14_col14, #T_d8eef_row15_col15, #T_d8eef_row16_col16, #T_d8eef_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col1, #T_d8eef_row4_col10, #T_d8eef_row10_col3, #T_d8eef_row11_col0, #T_d8eef_row13_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col2, #T_d8eef_row3_col16, #T_d8eef_row4_col15, #T_d8eef_row4_col16, #T_d8eef_row6_col17, #T_d8eef_row11_col16, #T_d8eef_row12_col5, #T_d8eef_row14_col5, #T_d8eef_row15_col5, #T_d8eef_row16_col0, #T_d8eef_row17_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col3, #T_d8eef_row0_col5, #T_d8eef_row4_col13, #T_d8eef_row4_col17, #T_d8eef_row6_col1, #T_d8eef_row6_col11, #T_d8eef_row7_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col4, #T_d8eef_row0_col14, #T_d8eef_row2_col16, #T_d8eef_row3_col15, #T_d8eef_row6_col16, #T_d8eef_row8_col16, #T_d8eef_row9_col17, #T_d8eef_row10_col5, #T_d8eef_row12_col16, #T_d8eef_row12_col17, #T_d8eef_row15_col16, #T_d8eef_row16_col14, #T_d8eef_row17_col3, #T_d8eef_row17_col13 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col6, #T_d8eef_row4_col6, #T_d8eef_row5_col7, #T_d8eef_row12_col4, #T_d8eef_row14_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col7 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d8eef_row0_col8, #T_d8eef_row8_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col9, #T_d8eef_row3_col12, #T_d8eef_row10_col1, #T_d8eef_row15_col11 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col10, #T_d8eef_row1_col0, #T_d8eef_row3_col7, #T_d8eef_row6_col14, #T_d8eef_row9_col0, #T_d8eef_row11_col4, #T_d8eef_row13_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col11, #T_d8eef_row4_col1, #T_d8eef_row16_col5, #T_d8eef_row17_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col12, #T_d8eef_row2_col1, #T_d8eef_row6_col3, #T_d8eef_row7_col16, #T_d8eef_row9_col16, #T_d8eef_row13_col4, #T_d8eef_row16_col2, #T_d8eef_row16_col9, #T_d8eef_row16_col15 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col13, #T_d8eef_row4_col9, #T_d8eef_row14_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col15, #T_d8eef_row5_col17, #T_d8eef_row12_col1, #T_d8eef_row13_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col16, #T_d8eef_row5_col0, #T_d8eef_row5_col9, #T_d8eef_row6_col5, #T_d8eef_row11_col17 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d8eef_row0_col17, #T_d8eef_row1_col5, #T_d8eef_row3_col17, #T_d8eef_row5_col16, #T_d8eef_row11_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col2, #T_d8eef_row3_col8, #T_d8eef_row6_col4, #T_d8eef_row13_col17, #T_d8eef_row15_col17, #T_d8eef_row16_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col3, #T_d8eef_row3_col9, #T_d8eef_row3_col11, #T_d8eef_row5_col10, #T_d8eef_row5_col11, #T_d8eef_row5_col15, #T_d8eef_row7_col17, #T_d8eef_row10_col17, #T_d8eef_row15_col3, #T_d8eef_row15_col4, #T_d8eef_row16_col3, #T_d8eef_row16_col10, #T_d8eef_row16_col11, #T_d8eef_row16_col12 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col4, #T_d8eef_row1_col6, #T_d8eef_row3_col0, #T_d8eef_row13_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col7, #T_d8eef_row2_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col8, #T_d8eef_row10_col8, #T_d8eef_row11_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col9, #T_d8eef_row1_col10, #T_d8eef_row2_col10, #T_d8eef_row2_col15, #T_d8eef_row7_col11, #T_d8eef_row15_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col11, #T_d8eef_row3_col14, #T_d8eef_row8_col2, #T_d8eef_row10_col2, #T_d8eef_row12_col2, #T_d8eef_row12_col8, #T_d8eef_row14_col15 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col12, #T_d8eef_row10_col0, #T_d8eef_row14_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col13, #T_d8eef_row4_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col14, #T_d8eef_row11_col1, #T_d8eef_row11_col15 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col15, #T_d8eef_row6_col13, #T_d8eef_row9_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d8eef_row1_col16, #T_d8eef_row1_col17, #T_d8eef_row6_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col0, #T_d8eef_row4_col0, #T_d8eef_row4_col8, #T_d8eef_row5_col14, #T_d8eef_row8_col5, #T_d8eef_row9_col4, #T_d8eef_row9_col5, #T_d8eef_row10_col4, #T_d8eef_row11_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_d8eef_row2_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_d8eef_row2_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d8eef_row2_col6, #T_d8eef_row2_col8, #T_d8eef_row8_col12, #T_d8eef_row11_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col7, #T_d8eef_row8_col7, #T_d8eef_row9_col14 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d8eef_row2_col11, #T_d8eef_row15_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col12, #T_d8eef_row6_col2, #T_d8eef_row8_col1, #T_d8eef_row10_col15, #T_d8eef_row12_col15, #T_d8eef_row14_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col13, #T_d8eef_row4_col14, #T_d8eef_row6_col10, #T_d8eef_row13_col6, #T_d8eef_row15_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col14, #T_d8eef_row12_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d8eef_row2_col17, #T_d8eef_row5_col8, #T_d8eef_row8_col4, #T_d8eef_row8_col17, #T_d8eef_row16_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d8eef_row3_col1, #T_d8eef_row5_col13, #T_d8eef_row9_col3, #T_d8eef_row13_col5, #T_d8eef_row14_col0, #T_d8eef_row14_col16, #T_d8eef_row14_col17, #T_d8eef_row16_col4, #T_d8eef_row16_col6, #T_d8eef_row17_col2, #T_d8eef_row17_col4, #T_d8eef_row17_col6, #T_d8eef_row17_col7, #T_d8eef_row17_col8, #T_d8eef_row17_col9, #T_d8eef_row17_col10, #T_d8eef_row17_col11, #T_d8eef_row17_col12, #T_d8eef_row17_col14, #T_d8eef_row17_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8eef_row3_col2, #T_d8eef_row5_col2, #T_d8eef_row15_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_d8eef_row3_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d8eef_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d8eef_row3_col6, #T_d8eef_row17_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d8eef_row3_col10 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d8eef_row3_col13, #T_d8eef_row14_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d8eef_row4_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_d8eef_row4_col3, #T_d8eef_row7_col2, #T_d8eef_row7_col8, #T_d8eef_row10_col9, #T_d8eef_row14_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d8eef_row4_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_d8eef_row4_col7, #T_d8eef_row12_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_d8eef_row4_col12, #T_d8eef_row10_col6, #T_d8eef_row12_col6, #T_d8eef_row14_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d8eef_row5_col1, #T_d8eef_row5_col6, #T_d8eef_row10_col16, #T_d8eef_row12_col0, #T_d8eef_row16_col7, #T_d8eef_row16_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d8eef_row5_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_d8eef_row5_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d8eef_row5_col12, #T_d8eef_row8_col3, #T_d8eef_row11_col3, #T_d8eef_

# %%
df.corr(method='pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_92fa1_row0_col0, #T_92fa1_row1_col1, #T_92fa1_row2_col2, #T_92fa1_row3_col3, #T_92fa1_row4_col4, #T_92fa1_row5_col5, #T_92fa1_row6_col6, #T_92fa1_row7_col7, #T_92fa1_row8_col8, #T_92fa1_row9_col9, #T_92fa1_row10_col10, #T_92fa1_row11_col11, #T_92fa1_row12_col12, #T_92fa1_row13_col13, #T_92fa1_row14_col14, #T_92fa1_row15_col15, #T_92fa1_row16_col16, #T_92fa1_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col1, #T_92fa1_row3_col12 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col2, #T_92fa1_row5_col1, #T_92fa1_row8_col3, #T_92fa1_row8_col16, #T_92fa1_row10_col5, #T_92fa1_row16_col3, #T_92fa1_row17_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col3, #T_92fa1_row0_col6, #T_92fa1_row0_col17, #T_92fa1_row1_col16, #T_92fa1_row4_col6, #T_92fa1_row4_col8, #T_92fa1_row4_col13, #T_92fa1_row5_col14, #T_92fa1_row8_col5, #T_92fa1_row9_col5, #T_92fa1_row12_col16, #T_92fa1_row12_col17, #T_92fa1_row16_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col4, #T_92fa1_row1_col2, #T_92fa1_row2_col1, #T_92fa1_row5_col6, #T_92fa1_row16_col1, #T_92fa1_row16_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col5, #T_92fa1_row3_col17, #T_92fa1_row4_col17, #T_92fa1_row5_col16, #T_92fa1_row13_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col8, #T_92fa1_row13_col15 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col9, #T_92fa1_row2_col13, #T_92fa1_row6_col14, #T_92fa1_row14_col7, #T_92fa1_row14_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col10, #T_92fa1_row1_col6, #T_92fa1_row6_col12, #T_92fa1_row12_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_col11, #T_92fa1_row6_col11, #T_92fa1_row14_col4, #T_92fa1_row15_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_92fa1_row0_
{
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_92fa1_row3_col10, #T_92fa1_row4_col14 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_92fa1_row3_col13, #T_92fa1_row10_col1, #T_92fa1_row12_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_92fa1_row4_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_92fa1_row4_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_92fa1_row4_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_92fa1_row4_col9, #T_92fa1_row4_col10, #T_92fa1_row6_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_92fa1_row4_col11, #T_92fa1_row8_col12, #T_92fa1_row9_col0, #T_92fa1_row11_col4, #T_92fa1_row12_col15, #T_92fa1_row14_col2, #T_92fa1_row15_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_92fa1_row5_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_92fa1_row5_col4, #T_92fa1_row7_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_92fa1_row5_col7, #T_92fa1_row5_col8, #T_92fa1_row6_col17, #T_92fa1_row7_col17, #T_92fa1_row9_col17, #T_92fa1_row13_col16, #T_92fa1_row13_col17, #T_92fa1_row15_col16, #T_92fa1_row16_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_92fa1_row6_col0, #T_92fa1_row6_col10, #T_92fa1_row10_col3, #T_92fa1_row13_col0, #T_92fa1_row14_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_92fa1_row6_col2, #T_92fa1_row10_col15, #T_92fa1_row15_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_92fa1_row6_col7, #T_92fa1_row7_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_92fa1_row6_col8 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_92fa1_row6_col9, #T_92fa1_row9_col6 {
#   background-co

# %%
df = xp
leal = df[df['Customer Type'] == 'Loyal Customer'].iloc[:200]
desleal = df[df['Customer Type'] == 'disloyal Customer'].iloc[:200]

df = pd.concat([leal, desleal])

# %%
df['Customer Type'] = df['Customer Type'].map({'Loyal Customer': 1, 'disloyal Customer': -1})

df['Age'] = (df['Age'])
df['Flight Distance'] = (df['Flight Distance'])
df['Gate location'] = (df['Gate location'])
df['Food and drink'] = (df['Food and drink'])
df['On-board service'] = (df['On-board service'])
df['Leg room service'] = (df['Leg room service'])
df['Baggage handling'] = (df['Baggage handling'])
df['Checkin service'] = (df['Checkin service'])

X = df[['Age', 'Flight Distance', 'Checkin service', 'Baggage handling', 'Leg room service', 'On-board service', 'Food and drink', 'Gate location']].values
y = df['Customer Type'].values

X = np.concatenate((X, np.ones((X.shape[0], 1))), axis=1)

w = np.dot(inv(np.dot(X.T, X)), np.dot(X.T, y))

w1, w2, w0 = w[0], w[1], w[8]

x_hyperplane = np.linspace(X[:, 0].min(), X[:, 0].max(), 1000)
y_hyperplane = (-w0 - w1 * x_hyperplane) / w2

plt.figure(figsize=(10, 6))
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label='Leal', c='blue')
plt.scatter(X[y == -1][:, 0], X[y == -1][:, 1], label='Desleal', c='red')
plt.plot(x_hyperplane, y_hyperplane, color='green', label='Hiperplano de Separação')
plt.xlabel('Type of Travel')
plt.ylabel('Inflight wifi service')
plt.legend()
plt.title('Gráfico de Dispersão com Classificador Linear e Reta de Separação')
plt.grid(True)
plt.show()

# %% [markdown]
# # Classifição Naive-Bayes

# %%
#Frequencia:
#    Não     Sim
#0 = 2     = 811  = 813/25976  = 0.0313%
#1 = 2966  = 1522 = 4488/25976 = 0.1727%
#2 = 4923  = 1567 = 6490/25976 = 0.2498%
#3 = 4694  = 1623 = 6317/25976 = 0.2431%
#4 = 1953  = 3028 = 4981/25976 = 0.1917%
#5 = 35    = 2852 = 2887/25976 = 0.1111%
#Total = 14573/25976 = 0.561% | 11403/25976 = 0.439%
#TotalTudo = 25976

#Prob ser insatisfeito e dar 0:
#P0N = 2/14573 PN = 14573/25976 P0 = 813/25976
PN0 = (2/14573) * (0.561)/(0.0313)
PS0 = 1 - PN0
#Prob ser insatisfeito e dar 1:
#P0N = 2/14573 PN = 14573/25976 813/25976
PN1 = (2966/14573) * (0.561)/(0.1727)
PS1 = 1 - PN1
#Prob ser insatisfeito e dar 2:
#P0N = 2/14573 PN = 14573/25976 813/25976
PN2 = (4923/14573) * (0.561)/(0.2498)
PS2 = 1 - PN2
#Prob ser insatisfeito e dar 3:
#P0N = 2/14573 PN = 14573/25976 813/25976
PN3 = (4694/14573) * (0.561)/(0.2431)
PS3 = 1 - PN3
#Prob ser insatisfeito e dar 4:
#P0N = 2/14573 PN = 14573/25976 813/25976
PN4 = (1953/14573) * (0.561)/(0.1917)
PS4 = 1 - PN4
#Prob ser insatisfeito e dar 5:
#P0N = 2/14573 PN = 14573/25976 813/25976
PN5 = (35/14573) * (0.561)/(0.1111)
PS5 = 1/100 - PN5

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['Type of Travel'] = df['Type of Travel'].map({'Business travel': 1, 'Personal Travel': 0})
df['Class'] = df['Class'].map({'Business': 1, 'Eco': -1, 'Eco Plus': 0})
df['satisfaction'] = df['satisfaction'].map({'satisfied': 1, 'neutral or dissatisfied': 0})

# %%
X = df.drop(['satisfaction'], axis = 1).values
y = df['satisfaction'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125, stratify = y
)

# %%
# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[6]])

print("Actual Value:", y_test[6])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: 1
# Predicted Value: 1

# %%
y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7878787878787878
# F1 Score: 0.7871085583503883

# %%
labels = [0,1]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %% [markdown]
# # Classificação Árvore de Decisão (simples)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y.astype(float))
tree.plot_tree(clf,filled=True)
y_pred = clf.predict(X_test)

# %%
labels = ["Leal", "Desleal"]
cm = confusion_matrix(y_test, y_pred)
labels = ["Leal", "Desleal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %%
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 1.0
# F1 Score: 1.0

# %% [markdown]
# # Classificação Rede Neural MLP

# %%
clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
clf.predict_proba(X_test[:1])
y_pred = clf.predict(X_test)
score = clf.score(X_test, y_test)
score
# Out:
# 0.6818181818181818

# %%
labels = ["Leal", "Desleal"]
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %% [markdown]
# # Random Florest

# %%
clf = RandomForestClassifier(n_estimators = 800)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8409090909090909

# %%
labels = ["Leal", "Desleal"]
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %% [markdown]
# # ROC

# %%
clf = SVC(random_state=0).fit(X_train, y_train)
y_pred = clf.decision_function(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred,name='class')
plt.show()
